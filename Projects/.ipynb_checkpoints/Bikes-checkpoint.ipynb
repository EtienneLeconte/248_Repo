# %%
import pandas as pd

# %%
traffic=pd.read_csv('/Users/etienneleconte/Downloads/comptage-velo-donnees-compteurs (1).csv', sep=';')

# %%
traffic.shape
# Out:
# (755470, 9)

# %%
traffic.head()
# Out:
#   Identifiant du compteur                    Nom du compteur  \
# 0            100003096-SC  97 avenue Denfert Rochereau SO-NE
# 1            100003096-SC  97 avenue Denfert Rochereau SO-NE
# 2            100003096-SC  97 avenue Denfert Rochereau SO-NE
# 3            100003096-SC  97 avenue Denfert Rochereau SO-NE
# 4            100003096-SC  97 avenue Denfert Rochereau SO-NE
#
#    Identifiant du site de comptage            Nom du site de comptage  \
# 0                        100003096  97 avenue Denfert Rochereau SO-NE
# 1                        100003096  97 avenue Denfert Rochereau SO-NE
# 2                        100003096  97 avenue Denfert Rochereau SO-NE
# 3                        100003096  97 avenue Denfert Rochereau SO-NE
# 4                        100003096  97 avenue Denfert Rochereau SO-NE
#
#    Comptage horaire  Date et heure de comptage  \
# 0                 1  2019-08-01T04:00:00+02:00
# 1                 0  2019-08-01T06:00:00+02:00
# ...

# %%
lanes=pd.read_csv('/Users/etienneleconte/Downloads/reseau-cyclable.csv', sep=';')
lanes
# Out:
#                                                Typologie  \
# 0                                       Pistes cyclables
# 1                                       Pistes cyclables
# 2                                       Pistes cyclables
# 3      Autres itinéraires cyclables (ex : Aires piéto...
# 4                                       Pistes cyclables
# ...                                                  ...
# 11949  Autres itinéraires cyclables (ex : Aires piéto...
# 11950  Autres itinéraires cyclables (ex : Aires piéto...
# 11951  Autres itinéraires cyclables (ex : Aires piéto...
# 11952  Autres itinéraires cyclables (ex : Aires piéto...
# 11953  Autres itinéraires cyclables (ex : Aires piéto...
#
#       Aménagement bidirectionnel  Régime de vitesse  \
# 0                            Oui            Zone 30
# 1                            Non            Voie 50
# 2                            Non            Voie 50
# 3                            Non  Zone de rencontre
# ...

# %%
lanes['Arrondissement'].isna().sum()
# Out:
# 3

# %%
accidents=pd.read_csv('/Users/etienneleconte/Downloads/accidents-velos (1).csv', sep=',',low_memory=False)
accidents.head()
# Out:
#    identifiant accident        date          mois          jour  heure  \
# 0          200500000030  2005-01-13  01 - janvier     3 - jeudi   19.0
# 1          200500000034  2005-01-19  01 - janvier  2 - mercredi   10.0
# 2          200500000078  2005-01-26  01 - janvier  2 - mercredi   13.0
# 3          200500000093  2005-01-03  01 - janvier     0 - lundi   13.0
# 4          200500000170  2005-01-29  01 - janvier    5 - samedi   18.0
#
#   departement commune     lat    lon en agglomeration  ... existence securite  \
# 0          62   62331  50.300  2.840              oui  ...                NaN
# 1          62   62022   0.000  0.000              non  ...                NaN
# 2          02   02173   0.000  0.000              non  ...             Casque
# 3          02   02810  49.255  3.094              oui  ...                NaN
# 4          76   76196   0.000  0.000              non  ...              Autre
#
#   usage securite obstacle fixe heurte obstacle mobile heurte  \
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65981 entries, 0 to 65980
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   identifiant accident        65981 non-null  int64
#  1   date                        65981 non-null  object
#  2   mois                        65981 non-null  object
#  3   jour                        65981 non-null  object
#  4   heure                       65515 non-null  float64
#  5   departement                 65981 non-null  object
#  6   commune                     65981 non-null  object
#  7   lat                         65981 non-null  float64
#  8   lon                         65713 non-null  float64
#  9   en agglomeration            65981 non-null  object
#  10  type intersection           65979 non-null  object
#  11  type collision              65977 non-null  object
#  12  luminosite                  65981 non-null  object
# ...

# %%
qqq=traffic.pivot_table(index='Identifiant du compteur', values='Coordonnées géographiques', aggfunc='head')

# %%
qqq=qqq['Coordonnées géographiques'].str.split(',',expand=True)

# %%
qqq=qqq.applymap(float)

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDY_0cvugGNzNXKCzdP1aYv8r2hV4JdWxE')

# %%
qqq.apply(lambda x: gmaps.reverse_geocode((x[0],x[1]))[0]['address_components'][-1]['long_name'], axis=1)
# Out:
# 0         75014
# 1         75014
# 2         75014
# 3         75014
# 4         75014
#           ...
# 752888    75018
# 752891    75018
# 752894    75018
# 752897    75018
# 752900    75018
# Length: 475, dtype: object
