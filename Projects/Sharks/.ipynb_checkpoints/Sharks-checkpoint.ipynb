# %%
import os 
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/etienneleconte/248_Repo/Projects/Sharks'

# %%
import chardet
with open('attacks.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df=pd.read_csv('attacks.csv',encoding='Windows-1252')

# %%
df.sample(10)
# Out:
#         Case Number                  Date    Year        Type    Country  \
# 7719              0                   NaN     NaN         NaN        NaN
# 13135           NaN                   NaN     NaN         NaN        NaN
# 18560           NaN                   NaN     NaN         NaN        NaN
# 5859   1877.02.17.R  Reported 17-Feb-1877  1877.0  Unprovoked  AUSTRALIA
# 7699              0                   NaN     NaN         NaN        NaN
# 21799           NaN                   NaN     NaN         NaN        NaN
# 9511            NaN                   NaN     NaN         NaN        NaN
# 7068              0                   NaN     NaN         NaN        NaN
# 7556              0                   NaN     NaN         NaN        NaN
# 1695     2004.02.21           21-Feb-2004  2004.0  Unprovoked  AUSTRALIA
#
#                   Area              Location  Activity           Name Sex   \
# 7719               NaN                   NaN       NaN            NaN  NaN
# 13135              NaN                   NaN       NaN            NaN  NaN
# 18560              NaN                   NaN       NaN            NaN  NaN
# 5859          Victoria         Off Melbourne  Fishing   Gesoun Gentel    M
# 7699               NaN                   NaN       NaN            NaN  NaN
# 21799              NaN                   NaN       NaN            NaN  NaN
# 9511               NaN                   NaN       NaN            NaN  NaN
# 7068               NaN                   NaN       NaN            NaN  NaN
# 7556               NaN                   NaN       NaN            NaN  NaN
# 1695   New South Wales  Taree, Old Bar Beach  Swimming           male    M
#
#        ... Species     Investigator or Source                      pdf  \
# 7719   ...      NaN                       NaN                      NaN
# 13135  ...      NaN                       NaN                      NaN
# 18560  ...      NaN                       NaN                      NaN
# 5859   ...      NaN  Otago Witness, 2/17/1877  1877.02.17.R-Gentel.pdf
# 7699   ...      NaN                       NaN                      NaN
# 21799  ...      NaN                       NaN                      NaN
# 9511   ...      NaN                       NaN                      NaN
# 7068   ...      NaN                       NaN                      NaN
# 7556   ...      NaN                       NaN                      NaN
# 1695   ...      NaN       Manning River Times     2004.02.21-Taree.pdf
#
#                                             href formula  \
# 7719                                                 NaN
# 13135                                                NaN
# 18560                                                NaN
# 5859   http://sharkattackfile.net/spreadsheets/pdf_di...
# 7699                                                 NaN
# 21799                                                NaN
# 9511                                                 NaN
# 7068                                                 NaN
# 7556                                                 NaN
# 1695   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                     href Case Number.1  \
# 7719                                                 NaN           NaN
# 13135                                                NaN           NaN
# 18560                                                NaN           NaN
# 5859   http://sharkattackfile.net/spreadsheets/pdf_di...  1877.02.17.R
# 7699                                                 NaN           NaN
# 21799                                                NaN           NaN
# 9511                                                 NaN           NaN
# 7068                                                 NaN           NaN
# 7556                                                 NaN           NaN
# 1695   http://sharkattackfile.net/spreadsheets/pdf_di...    2004.02.21
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 7719            NaN            NaN         NaN         NaN
# 13135           NaN            NaN         NaN         NaN
# 18560           NaN            NaN         NaN         NaN
# 5859   1877.02.17.R          444.0         NaN         NaN
# 7699            NaN            NaN         NaN         NaN
# 21799           NaN            NaN         NaN         NaN
# 9511            NaN            NaN         NaN         NaN
# 7068            NaN            NaN         NaN         NaN
# 7556            NaN            NaN         NaN         NaN
# 1695     2004.02.21         4608.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
df['Case Number'].isna().sum()
# Out:
# 17021
