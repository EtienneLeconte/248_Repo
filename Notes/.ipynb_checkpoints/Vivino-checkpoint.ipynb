# %%
import requests as r

# %%
url='https://www.vivino.com/chateau-palmer-margaux-grand-cru-classe/w/9220?ref=nav-search'

# %%
r.get(url).content
# Out:
# b"Your IP address (195.134.167.217) has been temporarily blocked for exceeding bulk request limits. If you believe this was done in error or you have legitimate needs to access our pages and data above and beyond these limits please contact admin@vivino.com with the subject 'Requests Blocked' and we'll try and resolve the issue."

# %%
headers="""authority: www.vivino.com
method: GET
path: /chateau-palmer-margaux-grand-cru-classe/w/9220?ref=nav-search
scheme: https
accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: max-age=0
cookie: first_time_visit=Q2VaU1dRUzE0UEMrVUswTDJOR0lZUT09LS1NUTVHa0Q0M2RRU3dZc1d6UlF5ZUJRPT0%3D--e215f4bd4a72ddd70947bc986cf08264979a4598; recently_viewed=cHdvNExtU2tZTTd6MkFaQUFITjRsZz09LS1MYXBrK1YzWE04MjZPU3R5QXV2djBnPT0%3D--f25f4bb13dd62819eed1677b1a64913bab90d859; client_cache_key=VDcvSnY5TFRBUU9BeHltMkR0cmw1OUpyVDNMQkdqYlBQb0pvdU5MWlIzaz0tLU1IUDVQd1JnMllSdHYvcW5ycmcxL2c9PQ%3D%3D--b66179c32bc6cc8fcdc7a3be8f585b51b9277a32; _ga=GA1.2.496113729.1599653445; _gid=GA1.2.1262014229.1599653445; __asc=9276072a17472c67f0bdeeb0c7e; __auc=9276072a17472c67f0bdeeb0c7e; _hjTLDTest=1; _hjid=561199b0-122b-472d-8fd3-a15b86dfe79b; _hjIncludedInSessionSample=1; _hjAbsoluteSessionInProgress=0; _hp2_ses_props.3503103446=%7B%22r%22%3A%22https%3A%2F%2Fwww.google.com%2F%22%2C%22ts%22%3A1599653446029%2C%22d%22%3A%22www.vivino.com%22%2C%22h%22%3A%22%2F%22%7D; deal_merchant_context=dFZZUXJOSm1zWFIzZ1Z3YzNxTVprUT09LS15VTlGNVh0TDFmc0RtR3cwQkFHVGhBPT0%3D--2dd2a512fecb9fbcd7916402804b3fc9150052cd; _hp2_id.3503103446=%7B%22userId%22%3A%223793161510345318%22%2C%22pageviewId%22%3A%228831597082585457%22%2C%22sessionId%22%3A%221767392756079548%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; _ruby-web_session=...--685c1b198150a1e2c36a9662b7ebf27ea4edc257
if-none-match: W/"b00ebd6585f85e0d571dd881eea73115"
sec-fetch-dest: document
sec-fetch-mode: navigate
sec-fetch-site: none
sec-fetch-user: ?1
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
resp=r.get(url,headers=headers)

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(resp.content)

# %%
soup.select('span.vintage')[0].text.strip()
# Out:
# 'Margaux (Grand Cru Classé)'

# %%
soup.select('div.row.location')
# Out:
# [<div class="row location">
#  <div class="mobile-column-6 tablet-column-12 desktop-column-12" id="wine-location-header"></div>
#  </div>]

# %%
script=soup.select('#master-wine-page-app+script')[0].contents[0]

# %%
script=script.split('window.__PRELOADED_STATE__.winePageInformation = ')[-1].split(';\n  window.__PRELOADED_STATE__.merchantId')[0]

# %%
script
# Out:
# '{"vintage":{"id":1510827,"seo_name":"chateau-palmer-margaux-grand-cru-classe-uv","name":"Château Palmer Margaux (Grand Cru Classé) U.V.","statistics":{"status":"Normal","ratings_count":20934,"ratings_average":4.5,"labels_count":1373,"reviews_count":67},"organic_certification_id":null,"certified_biodynamic":null,"image":{"location":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pl_480x640.png","variations":{"bottle_large":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pb_x960.png","bottle_medium":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pb_x600.png","bottle_medium_square":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pb_600x600.png","bottle_small":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pb_x300.png","bottle_small_square":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pb_300x300.png","label":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pl_480x640.png","label_large":"//images.vivino.com/thumbs/__WPtj65SDezq2usXsGcQg_pl_375x500.png","label_med
# ...

# %%
import json
script=json.loads(script)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-61-e3de05b2b17f> in <module>
#       1 import json
# ----> 2 script=json.loads(script)
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
# ...
